# %%
import pandas as pd

# %%
data=pd.read_csv("customer_data.csv")

# %%
data
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0          01-01-2019          151200  Female  19.0         Single
# 1          02-01-2019          151201    Male  49.0         Single
# 2          03-01-2019          151202    Male  63.0        Married
# 3          04-01-2019          151203     NaN  18.0         Single
# 4          05-01-2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507       12-11-2025          153695  Female  57.0         Single
# 2508       13-11-2025          153696  Female  36.0        Married
# 2509       14-11-2025          153697    Male  22.0         Single
# 2510       15-11-2025          153698     NaN  44.0         Single
# 2511       16-11-2025          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
data.describe()
# Out:
#        Transaction_ID          Age      Referal  Amount_spent
# count     2512.000000  2470.000000  2357.000000   2270.000000
# mean    152443.931131    46.637652     0.652100   1418.422577
# std        724.580482    18.186277     0.476405    878.507451
# min     151200.000000    15.000000     0.000000      2.090000
# 25%     151815.750000    32.000000     0.000000    678.192500
# 50%     152443.500000    47.000000     1.000000   1341.435000
# 75%     153071.250000    62.000000     1.000000   2038.102500
# max     153699.000000    78.000000     1.000000   2999.980000

# %%
data["Age"].mean()
# Out:
# np.float64(46.63765182186235)

# %%
data["Age"].median()
# Out:
# np.float64(47.0)

# %%
data["Age"].mode()
# Out:
# 0    54.0
# Name: Age, dtype: float64

# %%
data["Age"].std()
# Out:
# np.float64(18.186276792698017)

# %%
data["Age"].min()
# Out:
# np.float64(15.0)

# %%
data["Age"].max()
# Out:
# np.float64(78.0)

# %%
data['State_names'].unique() #This method returns an array of unique values within a specified column
# Out:
# array(['Kansas', 'Illinois', 'New Mexico', 'Virginia', 'Connecticut',
#        'Hawaii', 'Florida', 'Vermont', 'California', 'Colorado', 'Iowa',
#        'South Carolina', 'New York', 'Maine', 'Maryland', 'Missouri',
#        'North Dakota', 'Ohio', 'Nebraska', 'Montana', 'Indiana',
#        'Wisconsin', 'Alabama', 'Arkansas', 'Pennsylvania',
#        'New Hampshire', 'Washington', 'Texas', 'Kentucky',
#        'Massachusetts', 'Wyoming', 'Louisiana', 'North Carolina',
#        'Rhode Island', 'West Virginia', 'Tennessee', 'Oregon', 'Alaska',
#        'Oklahoma', 'Nevada', 'New Jersey', 'Michigan', 'Utah', 'Arizona',
#        'South Dakota', 'Georgia', 'Idaho', 'Mississippi', 'Minnesota',
#        'Delaware'], dtype=object)

# %%
data['State_names'].nunique() # provide number of unique value( eg 50 in this case)
# Out:
# 50

# %%
data['Gender'].nunique()
# Out:
# 2

# %%
data["Gender"].value_counts() # provide no. of males and females
# Out:
# Gender
# Female    1356
# Male      1128
# Name: count, dtype: int64

# %%
data.sort_values(by='State_names')
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 617        09-09-2020          151805    Male  43.0        Married
# 1856       31-01-2024          153044  Female  18.0        Married
# 2443       09-09-2025          153631    Male  60.0        Married
# 2441       07-09-2025          153629    Male  18.0         Single
# 1023       20-10-2021          152211  Female  30.0        Married
# ...               ...             ...     ...   ...            ...
# 1789       25-11-2023          152977  Female  36.0        Married
# 1811       17-12-2023          152999    Male  71.0        Married
# 1819       25-12-2023          153007    Male  35.0        Married
# 1844       19-01-2024          153032  Female  24.0        Married
# 119        30-04-2019          151307  Female  43.0        Married
#
#      State_names   Segment Employees_status Payment_method  Referal  \
# 617      Alabama    Silver        Employees         PayPal      1.0
# ...

# %%
data.sort_values(by='State_names').head()
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 617        09-09-2020          151805    Male  43.0        Married
# 1856       31-01-2024          153044  Female  18.0        Married
# 2443       09-09-2025          153631    Male  60.0        Married
# 2441       07-09-2025          153629    Male  18.0         Single
# 1023       20-10-2021          152211  Female  30.0        Married
#
#      State_names   Segment Employees_status Payment_method  Referal  \
# 617      Alabama    Silver        Employees         PayPal      1.0
# 1856     Alabama    Silver          workers         PayPal      NaN
# 2443     Alabama  Platinum        Employees         PayPal      1.0
# 2441     Alabama  Platinum        Employees           Card      0.0
# 1023     Alabama  Platinum     Unemployment          Other      0.0
#
#       Amount_spent
# 617          87.88
# 1856       2091.73
# 2443           NaN
# 2441        289.85
# 1023           NaN

# %%
data["Amount_spent"].nsmallest()
# Out:
# 2468    2.09
# 568     2.16
# 2401    2.84
# 962     5.31
# 860     5.55
# Name: Amount_spent, dtype: float64

# %%
data["Amount_spent"].nlargest()
# Out:
# 17      2999.98
# 485     2998.62
# 2279    2997.21
# 589     2997.15
# 743     2996.82
# Name: Amount_spent, dtype: float64

# %% [markdown]
# data[data["Payment_method"] == 'paypal']

# %%
data[data['Payment_method'] == 'PayPal'] # printing whose payment methods is PayPal
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2          03-01-2019          151202    Male  63.0        Married
# 5          06-01-2019          151205    Male  71.0         Single
# 6          07-01-2019          151206  Female  34.0        Married
# 7          08-01-2019          151207    Male  37.0        Married
# 10         11-01-2019          151210  Female  56.0        Married
# ...               ...             ...     ...   ...            ...
# 2503       08-11-2025          153691    Male  67.0         Single
# 2508       13-11-2025          153696  Female  36.0        Married
# 2509       14-11-2025          153697    Male  22.0         Single
# 2510       15-11-2025          153698     NaN  44.0         Single
# 2511       16-11-2025          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2         New Mexico     Basic          workers         PayPal      1.0
# ...

# %%
con=data['Payment_method']=='PayPal' # 2nd methods-- printing whose payment methods is PayPal
data[con]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2          03-01-2019          151202    Male  63.0        Married
# 5          06-01-2019          151205    Male  71.0         Single
# 6          07-01-2019          151206  Female  34.0        Married
# 7          08-01-2019          151207    Male  37.0        Married
# 10         11-01-2019          151210  Female  56.0        Married
# ...               ...             ...     ...   ...            ...
# 2503       08-11-2025          153691    Male  67.0         Single
# 2508       13-11-2025          153696  Female  36.0        Married
# 2509       14-11-2025          153697    Male  22.0         Single
# 2510       15-11-2025          153698     NaN  44.0         Single
# 2511       16-11-2025          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2         New Mexico     Basic          workers         PayPal      1.0
# ...

# %%
cond1 = data['Payment_method'] == 'PayPal' 
cond2 = data['Marital_status'] == 'Married'

# %%
data[cond1 & cond2] # two condition checking
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2          03-01-2019          151202    Male  63.0        Married
# 6          07-01-2019          151206  Female  34.0        Married
# 7          08-01-2019          151207    Male  37.0        Married
# 10         11-01-2019          151210  Female  56.0        Married
# 16         17-01-2019          151216  Female  72.0        Married
# ...               ...             ...     ...   ...            ...
# 2489       25-10-2025          153677  Female  77.0        Married
# 2490       26-10-2025          153678  Female  50.0        Married
# 2492       28-10-2025          153680  Female  33.0        Married
# 2494       30-10-2025          153682    Male  56.0        Married
# 2508       13-11-2025          153696  Female  36.0        Married
#
#       State_names   Segment Employees_status Payment_method  Referal  \
# 2      New Mexico     Basic          workers         PayPal      1.0
# ...

# %%
data[['Age', 'Amount_spent']].groupby(data['Gender']).max() #display the data create group based on gender
display age and amount spent
# Out:
#          Age  Amount_spent
# Gender
# Female  78.0       2999.98
# Male    78.0       2998.62
